# %%
import pandas as pd

# %%
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### To - Do - 1

# %%
df = pd.read_csv('//content/drive/MyDrive/Concept And Technologies of AI/student (1).csv')
df.head()
# Out:
#    Math  Reading  Writing
# 0    48       68       63
# 1    62       81       72
# 2    79       80       78
# 3    76       83       79
# 4    59       64       62

# %%
df.tail()
# Out:
#      Math  Reading  Writing
# 995    72       74       70
# 996    73       86       90
# 997    89       87       94
# 998    83       82       78
# 999    66       66       72

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Math     1000 non-null   int64
#  1   Reading  1000 non-null   int64
#  2   Writing  1000 non-null   int64
# dtypes: int64(3)
# memory usage: 23.6 KB

# %%
df.describe()
# Out:
#               Math      Reading      Writing
# count  1000.000000  1000.000000  1000.000000
# mean     67.290000    69.872000    68.616000
# std      15.085008    14.657027    15.241287
# min      13.000000    19.000000    14.000000
# 25%      58.000000    60.750000    58.000000
# 50%      68.000000    70.000000    69.500000
# 75%      78.000000    81.000000    79.000000
# max     100.000000   100.000000   100.000000

# %%
X = df[['Math', 'Reading']] # Feature
print(X.head())
# Out:
#    Math  Reading
# 0    48       68
# 1    62       81
# 2    79       80
# 3    76       83
# 4    59       64

# %%
Y = df['Writing'] # Label
print(Y.head())
# Out:
# 0    63
# 1    72
# 2    78
# 3    79
# 4    62
# Name: Writing, dtype: int64

# %% [markdown]
# ### To - Do - 2

# %%
math = df['Math'].to_numpy() # convert dataframe to numpy array

# %%
read = df['Reading'].to_numpy()

# %%
write = df['Writing'].to_numpy()

# %%
X = np.array([math, read])

# %%
W = np.zeros((2, 1))

# %%
Y_pred = W.T @ X

# %%
print("X shape (d x n):", X.shape)
# Out:
# X shape (d x n): (2, 1000)

# %%
print("W shape (d x 1):", W.shape)
# Out:
# W shape (d x 1): (2, 1)

# %%
print("Y shape (1 x n):", Y.shape)
# Out:
# Y shape (1 x n): (1, 1000)

# %%
print(Y_pred.shape)
# Out:
# (1, 1000)

# %% [markdown]
# ### To - Do - 3

# %%
from sklearn.model_selection import train_test_split

# %%
X_sklearn = df[['Math', 'Reading']].to_numpy()

# %%
Y_sklearn = df['Writing'].to_numpy()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_sklearn, Y_sklearn, test_size=0.2, random_state=42)

# %%
print("Training Features shape:", X_train.shape)
# Out:
# Training Features shape: (800, 2)

# %%
print("Test Features shape:", X_test.shape)
# Out:
# Test Features shape: (200, 2)

# %%
print("Training Target shape:", Y_train.shape)
# Out:
# Training Target shape: (800,)

# %%
print("Test Target shape:", Y_test.shape)
# Out:
# Test Target shape: (200,)

# %% [markdown]
# ### To - Do - 4

# %%
def cost_function(X, Y, W):
  """
  Parameters:
  This function finds the Mean Square Error.
  Input parameters:
    X: Feature Matrix
    Y: Target Matrix
    W: Weight Matrix
  Output Parameters:
    cost: accumulated mean square error.
  """
  Y_pred = W.T @ X
  n = Y.shape[1]
  cost = np.sum((Y_pred - Y) ** 2) / (2 * n)
  return cost

# %% [markdown]
# ### To - Do - 5:

# %%
X_test = np.array([[1, 3, 5], [2, 4, 6]])
Y_test = np.array([[3, 7, 11]])
W_test = np.array([[1], [1]])
cost = cost_function(X_test, Y_test, W_test)
if cost == 0:
  print("Proceed Further")
else:
  print("Something went wrong: Reimplement the cost function")
  print("Cost function output:", cost_function(X_test, Y_test, W_test))
# Out:
# Proceed Further

# %% [markdown]
# ### To - Do - 6

# %%
import numpy as np

# %%
def gradient_descent(X, Y, W, alpha, iterations):
  """
  Perform gradient descent to optimize the parameters of a linear regression model.
  Parameters:
    X (numpy.ndarray): Feature matrix (m x n).
    Y (numpy.ndarray): Target vector (m x 1).
    W (numpy.ndarray): Initial guess for parameters (n x 1).
    alpha (float): Learning rate.
    iterations (int): Number of iterations for gradient descent.
  Returns:
    tuple: A tuple containing the final optimized parameters (W_update) and
    the history of cost values.
    W_update (numpy.ndarray): Updated parameters (n x 1).
    cost_history (list): History of cost values over iterations.
  """
  # Initialize cost history
  cost_history = [0] * iterations
  # Number of samples
  m = len(Y)
  for iteration in range(iterations):
    # Step 1: Hypothesis Values
    Y_pred = X.dot(W)
    # Step 2: Difference between Hypothesis and Actual Y
    loss = Y_pred - Y
    # Step 3: Gradient Calculation
    dw = (X.T.dot(loss)) / m
    # Step 4: Updating Values of W using Gradient
    W = W - alpha * dw
    # Step 5: New Cost Value
    cost = np.sum(loss ** 2) / (2 * m)
    cost_history[iteration] = cost
  return W, cost_history

# %% [markdown]
# ### To - Do - 7

# %%
# Generate random test data
np.random.seed(0) # For reproducibility
X = np.random.rand(100, 3) # 100 samples, 3 features
Y = np.random.rand(100)
W = np.random.rand(3) # Initial guess for parameters
# Set hyperparameters
alpha = 0.01
iterations = 1000
# Test the gradient_descent function
final_params, cost_history = gradient_descent(X, Y, W, alpha, iterations)
# Print the final parameters and cost history
print("Final Parameters:", final_params)
print("Cost History:", cost_history)
# Out:
# Final Parameters: [0.20551667 0.54295081 0.10388027]
# ...

# %% [markdown]
# ### To - Do - 8

# %%
# Model Evaluation - RMSE
def rmse(Y, Y_pred):
  """
  This Function calculates the Root Mean Squres.
  Input Arguments:
  Y: Array of actual(Target) Dependent Varaibles.
  Y_pred: Array of predeicted Dependent Varaibles.
  Output Arguments:
  rmse: Root Mean Square.
  """
  rmse = np.sqrt(np.sum((Y - Y_pred) ** 2) / len(Y))
  return rmse

# %% [markdown]
# ### To - Do - 9

# %%
# Model Evaluation - R2
def r2(Y, Y_pred):
  """
  This Function calculates the R Squared Error.
  Input Arguments:
    Y: Array of actual(Target) Dependent Varaibles.
    Y_pred: Array of predeicted Dependent Varaibles.
  Output Arguments:
    rsquared: R Squared Error.
  """
  mean_y = np.mean(Y)
  ss_tot = sum((Y - mean_y) ** 2)
  ss_res = sum((Y - Y_pred) ** 2)
  r2 = 1 - (ss_res / ss_tot)
  return r2

# %% [markdown]
# ### To - Do - 10

# %%
# Main Function
def main():
  # Step 1: Load the dataset
  data = pd.read_csv('//content/drive/MyDrive/Concept And Technologies of AI/student (1).csv')

  # Step 2: Split the data into features (X) and target (Y)
  X = data[['Math', 'Reading']].values # Features: Math and Reading marks
  Y = data['Writing'].values # Target: Writing marks

  # Step 3: Split the data into training and test sets (80% train, 20% test)
  X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

  # Step 4: Initialize weights (W) to zeros, learning rate and number of iterations
  W = np.zeros(X_train.shape[1]) # Initialize weights
  alpha = 0.00001 # Learning rate
  iterations = 1000 # Number of iterations for gradient descent

  # Step 5: Perform Gradient Descent
  W_optimal, cost_history = gradient_descent(X_train, Y_train, W, alpha, iterations)

  # Step 6: Make predictions on the test set
  Y_pred = np.dot(X_test, W_optimal)

  # Step 7: Evaluate the model using RMSE and R-Squared
  model_rmse = rmse(Y_test, Y_pred)
  model_r2 = r2(Y_test, Y_pred)

  # Step 8: Output the results
  print("Final Weights:", W_optimal)
  print("Cost History (First 10 iterations):", cost_history[:10])
  print("RMSE:", model_rmse)
  print("R-Squared:", model_r2)

# Execute the main function
if __name__ == "__main__":
  main()
# Out:
# Final Weights: [0.34811659 0.64614558]
# Cost History (First 10 iterations): [np.float64(2471.69875), np.float64(2013.165570783755), np.float64(1640.286832599692), np.float64(1337.0619994901585), np.float64(1090.4794892850578), np.float64(889.9583270083234), np.float64(726.8940993009545), np.float64(594.2897260808594), np.float64(486.4552052951635), np.float64(398.7634463599484)]
# RMSE: 5.2798239764188635
# R-Squared: 0.8886354462786421

# %% [markdown]
# ### To - Do - 11

# %% [markdown]
# The model performance is acceptable , the metrices shows good generalization, with low RMSE and a high R^2 (close to 1), indicating neither overfitting nor underfitting.

# %% [markdown]
# When the learning rate is set too high, the weights become nan(not a number) because the updates were too large, causing overflow in calculation. Similarly, when the learning rate is too small, the weight updates are tiny, and the model barely moves toward minimizing the cost.
