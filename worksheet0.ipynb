# %% [markdown]
# ### Python Version Check

# %%
import sys

# %%
if sys.version_info.major == 3 and sys.version_info.minor >= 6:
  print("Hello, World!")
  print(f"Python version: {sys.version}")
else:
  print("Please use Python 3.6 or higher.")
# Out:
# Hello, World!
# Python version: 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# ### Data Types - Numeric

# %%
age = 23

# %%
pi = 3.14

# %%
temperature = -5.5

# %%
print("data type of variable age = ",type(age))
# Out:
# data type of variable age =  <class 'int'>

# %%
print("data type of variable pi = ",type(pi))
# Out:
# data type of variable pi =  <class 'float'>

# %%
print("data type of variable temperature=  ",type(temperature))
# Out:
# data type of variable temperature=   <class 'float'>

# %% [markdown]
# ### Data Types - Sequence - String

# %%
name = "Alice"

# %%
greeting = "Hello"

# %%
address = "123 Main St"

# %%
print("data type of the variable name = ", type(name))
# Out:
# data type of the variable name =  <class 'str'>

# %%
print("data type of the variable greeting = ", type(greeting))
# Out:
# data type of the variable greeting =  <class 'str'>

# %%
print("data type of the variable address = ",type(address))
# Out:
# data type of the variable address =  <class 'str'>

# %%
print("The first letter of the name is:", name[0])
# Out:
# The first letter of the name is: A

# %%
print("The last letter of the name is:", name[-1])
# Out:
# The last letter of the name is: e

# %%
print("The second letter to the fourth of the name is:", name[1:4])
# Out:
# The second letter to the fourth of the name is: lic

# %%
print("The first two letters of the name are:", name[:2])
# Out:
# The first two letters of the name are: Al

# %%
print("Substring starting from the third letter is:", name[2:])
# Out:
# Substring starting from the third letter is: ice

# %% [markdown]
# ### Data Types - Sequence - List

# %%
list1 = [1, 2, 3, 4]

# %%
mixed_list = [12, "Hello", True]

# %%
mixed_list[0] = False
mixed_list
# Out:
# [False, 'Hello', True]

# %% [markdown]
# ### Data Types - Sequence - Tuple

# %%
colors = ("red", "green", "yellow", "blue")

# %%
print("First element:", colors[0])
# Out:
# First element: red

# %%
print("Last two elements:", colors[2:])
# Out:
# Last two elements: ('yellow', 'blue')

# %%
print("Middle two elements:", colors[1:3])
# Out:
# Middle two elements: ('green', 'yellow')

# %%
colors[0] = "purple"
colors
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-607839663.py in <cell line: 0>()
# ----> 1 colors[0] = "purple"
#       2 colors
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### Data Types - Sequence - Dict

# %%
person = {'name':'John','age':30,'city':'Pittsburgh'}

# %%
print(f"Hello my name is {person['name']}. I am {person['age']} years old and I live at {person['city']}.")
# Out:
# Hello my name is John. I am 30 years old and I live at Pittsburgh.

# %%
print("All keys:", list(person.keys()))
# Out:
# All keys: ['name', 'age', 'city']

# %% [markdown]
# ### Data Types - Set

# %%
print("All values:", list(person.values()))
# Out:
# All values: ['John', 30, 'Pittsburgh']

# %% [markdown]
# ### Data Types - Boolean

# %%
unique_numbers = {1, 2, 3, 3, 3, 3, 4, 5}
print(unique_numbers)
# Out:
# {1, 2, 3, 4, 5}

# %%
is_student = True

# %%
has_license = False

# %%
print("data type of the variable is_student = ",type(is_student))
# Out:
# data type of the variable is_student =  <class 'bool'>

# %%
print("data type of the variable has_license = ",type(has_license))
# Out:
# data type of the variable has_license =  <class 'bool'>

# %% [markdown]
# ### Sample Code - if-else statement

# %%
result = None

# %%
num = 10

# %% [markdown]
# ### Sample Code - Comparision Operator

# %%
if num > 0:
  print("Positive")
elif num == 0:
  print("Zero")
else:
  print("Non-positive")
# Out:
# Positive

# %%
x = 5

# %%
y = 10

# %% [markdown]
# ### Sample Code - Logical Operator

# %%
if x > 0 and y < 20:
  print("Both conditions are true")
if x > 0 or y > 20:
  print("At least one condition is true")
if not x == 0:
  print("x is not equal to 0")
# Out:
# Both conditions are true
# At least one condition is true
# x is not equal to 0

# %%
a = True

# %%
b = False

# %%
if a and b:
  print("Both a and b are True")
else:
  print("Either a or b is False")
# Out:
# Either a or b is False

# %%
if a or b:
  print("At least one of a or b is True")
else:
  print("Both a and b are False")
# Out:
# At least one of a or b is True

# %% [markdown]
# ### Sample Code - Various Loops

# %%
if not a:
  print("a is False")
else:
  print("a is True")
# Out:
# a is True

# %%
fruits = ["apple", "banana","cherry"]

# %%
for fruit in fruits:
  print(fruit)
# Out:
# apple
# banana
# cherry

# %%
count = 0
while count < 5:
  print("Count is:", count)
  count += 1
# Out:
# Count is: 0
# Count is: 1
# Count is: 2
# Count is: 3
# Count is: 4

# %%
fruits = ["apple", "banana", "orange"]

# %%
print("loop 1")
# Out:
# loop 1

# %%
for fruit in fruits:
  print(fruit)
  if fruit == "apple":
    break
# Out:
# apple

# %%
print("loop 2")
# Out:
# loop 2

# %% [markdown]
# ### Correct way to Write Function

# %%
for fruit in fruits:
  if fruit == "apple":
    continue
  else:
    print(fruit)
# Out:
# banana
# orange

# %% [markdown]
# ### Example on Built - in - Function

# %%
def add_binary(a, b):
  '''
  Returns the sum of two decimal numbers in binary digits.
  Parameters:
    a (int): A decimal integer
    b (int): Another decimal integer
  Returns:
    binary_sum (str): Binary string of the sum of a and b
  '''
  binary_sum = bin(a+b)[2:]
  return binary_sum
print(add_binary(2,3))
# Out:
# 101

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
length = len("Hello")
print (length)
# Out:
# 5

# %%
data_type = type(42)
print (data_type)
# Out:
# <class 'int'>

# %% [markdown]
# ### Example on Built - in - Methods

# %%
total = sum([1, 2, 3])
print (total)
# Out:
# 6

# %%
message = "hello".upper()
print(message)
# Out:
# HELLO

# %%
fruits = ["apple", "banana"]

# %%
fruits.append("cherry")
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
info = {"name": "Alice", "age": 25}

# %% [markdown]
# ### Example of well-structured user-defined function

# %%
age = info.get("age")
print(age)
# Out:
# 25

# %%
def temperature_converter():
  """
  Converts temperature between Celsius and Fahrenheit.
  This function prompts the user to specify the conversion type (Celsius to Fahrenheit
  or Fahrenheit to Celsius)
  and then asks for the temperature value. It calculates and returns the converted
  temperature.
  Returns:
  float: The converted temperature value.
  """
  print("Choose conversion type:")
  print("1. Celsius to Fahrenheit")
  print("2. Fahrenheit to Celsius")

  choice = input("Enter 1 or 2: ")
  if choice == "1":
    celsius = float(input("Enter temperature in Celsius: "))
    fahrenheit = (celsius * 9/5) + 32
    print(f"{celsius}C is equal to {fahrenheit}F")
    return fahrenheit
  elif choice == "2":
    fahrenheit = float(input("Enter temperature in Fahrenheit: "))
    celsius = (fahrenheit - 32) * 5/9
    print(f"{fahrenheit}F is equal to {celsius}C")
    return celsius
  else:
    print("Invalid choice. Please enter 1 or 2.")
    return None
temperature_converter()
# Out:
# Choose conversion type:
# 1. Celsius to Fahrenheit
# 2. Fahrenheit to Celsius
# Enter 1 or 2: 1
# Enter temperature in Celsius: 36
# 36.0C is equal to 96.8F
# 96.8

# %% [markdown]
# ### Global Variable

# %%
x = 10
def print_global():
  print(x)
print_global()
# Out:
# 10

# %% [markdown]
# ### Local Variable

# %%
def print_local():
    u = 5
    print(u)
print_local()
print(u)
# Out:
# 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2127180754.py in <cell line: 0>()
#       3     print(u)
#       4 print_local()
# ----> 5 print(u)
#
# NameError: name 'u' is not defined

# %% [markdown]
# ### Modify global variables

# %%
x = 10
def modify_global():
  global x
  x = 20
modify_global()
print(x)
# Out:
# 20

# %%
# Daily time (in hours): [study, entertainment, sleep]
time_data = [
  (3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
  (4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
  (5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
  (3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
  (4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
]

# %% [markdown]
# ### Task1

# %% [markdown]
# 1. Create empty lists for study time classifications:
# (a) Low: less than 3 hours.
# (b) Moderate: between 3 and 5 hours.
# (c) High: more than 5 hours.

# %%
low_study_time = []
moderate_study_time = []
high_study_time = []

# %% [markdown]
# 2. Iterate over the time_data list and add each study hour to the appropriate category.

# %%
for study, entertainment, sleep in time_data:
  if study < 3.0:
    low_study_time.append((study))
  elif study >= 3 and study <= 5:
    moderate_study_time.append((study))
  else:
    high_study_time.append((study))

# %% [markdown]
# 3. Print the lists to verify the classifications.

# %%
print("The list of students with low study hours i.e. less than 3 hours is: ",low_study_time)
print("The list of students with moderate study hours i.e. between 3 and 5 hours is: ",moderate_study_time)
print("The list of students with high study hours i.e. more than hours is: ",high_study_time)
# Out:
# The list of students with low study hours i.e. less than 3 hours is:  [2.5, 1.5, 2.0, 2.5]
# The list of students with moderate study hours i.e. between 3 and 5 hours is:  [3.5, 5.0, 4.0, 3.0, 4.5, 3.0, 4.0, 5.0, 3.5]
# The list of students with high study hours i.e. more than hours is:  [5.5, 6.0]

# %% [markdown]
# ### Task 2

# %% [markdown]
# 1. How many days had low study time?

# %%
low_study_days = len(low_study_time)
print("The total days that had low study time is: ", low_study_days)
# Out:
# The total days that had low study time is:  4

# %% [markdown]
# 2. How many days had moderate study time?

# %%
moderate_study_days = len(moderate_study_time)
print("The total days that had moderate study time is: ", moderate_study_days)
# Out:
# The total days that had moderate study time is:  9

# %% [markdown]
# 3. How many days had high study time?

# %%
high_study_days = len(high_study_time)
print("The total days that had high study time is: ", high_study_days)
# Out:
# The total days that had high study time is:  2

# %% [markdown]
# ### Task 3

# %% [markdown]
# Convert each study hour value into minutes and store it in a new list called study_minutes.
# 1. Iterate over the time_data list and apply the formula to the study hours.
# 2. Store the results in the new list.
# 3. Print the converted values.

# %%
study_minutes = []
for study, entertainment, sleep in time_data:
  study_minutes.append(study * 60)
print(study_minutes)
# Out:
# [210.0, 300.0, 150.0, 240.0, 90.0, 180.0, 330.0, 120.0, 270.0, 180.0, 360.0, 150.0, 240.0, 300.0, 210.0]

# %% [markdown]
# ### Task 4

# %% [markdown]
# 1. Create empty lists for study_hours, entertainment_hours, and sleep_hours.

# %%
study_hours = []
entertainment_hours = []
sleep_hours = []

# %% [markdown]
# 2. Iterate over time_data and extract values into each list.

# %%
for study, entertainment, sleep in time_data:
    study_hours.append(study)
    entertainment_hours.append(entertainment)
    sleep_hours.append(sleep)

# %% [markdown]
# 3. Calculate and print:
# (a) Average hours spent studying.
# (b) Average hours spent on entertainment.
# (c) Average hours spent sleeping.

# %%
avg_study_hours = sum(study_hours) / len(study_hours)
print("Average hours spent studying: ", avg_study_hours)
# Out:
# Average hours spent studying:  3.7

# %%
avg_entertainment_hours = sum(entertainment_hours) / len(entertainment_hours)
print("Average hours spent on entertainment: ",avg_entertainment_hours)
# Out:
# Average hours spent on entertainment:  2.5

# %%
avg_sleep_hours = sum(sleep_hours) / len(sleep_hours)
print("Average hours spent sleeping: ",avg_sleep_hours)
# Out:
# Average hours spent sleeping:  7.166666666666667

# %% [markdown]
# ### Task 5

# %% [markdown]
# 1. Import matplotlib.pyplot as plt.

# %%
import matplotlib.pyplot as plt

# %%
time_data = [
(3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
(4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
(5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
(3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
(4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
]

# %% [markdown]
# 2. Plot a scatter plot with:
# • x-axis: Study hours
# • y-axis: Sleep hours
# 3. Add labels, title, and color.

# %%
study_hours = [day[0] for day in time_data]
sleep_hours = [day[2] for day in time_data]
plt.scatter(study_hours, sleep_hours, color = "red")
plt.xlabel("Study hours")
plt.ylabel("Sleep hours")
plt.title("Study vs Sleep Pattern")
plt.grid(True, linestyle='--')
plt.show()

# %% [markdown]
# ### Reccursive Approach for finding factorial of a Number.

# %%
def factorial(n):
  if n == 0:
    return 1
  else:
    return n * factorial(n-1)

print (factorial(5))
# Out:
# 120

# %% [markdown]
# ### Task 1 - Sum of Nested Lists

# %%
def sum_nested_list(nested_list):
  """
  Calculate the sum of all numbers in a nested list.
  This function takes a list that may contain integers and other nested lists. It recursively traverses the list and sums all the integers, no matter how deeply nested they are.
  Args:
    nested_list (list): A list that may contain integers or other lists of integers.
  Returns:
    int: The total sum of all integers in the nested list, including those in sublists .
  Example:
    >>> sum_nested_list([1, [2, [3, 4], 5], 6, [7, 8]])
    36
    >>> sum_nested_list([1, [2, 3], [4, [5]]])
    15
  """
  total = 0
  for element in nested_list:
    if isinstance(element, list):
      total += sum_nested_list(element)
    else:
      total += element
  return total

# %% [markdown]
# • Test the function with a sample nested list, such as
# nested_list = [1, [2, [3, 4], 5], 6, [7, 8]].
# The result should be the total sum of all the numbers.

# %%
nested_list = [1, [2, [3, 4], 5], 6, [7, 8]]
print(sum_nested_list(nested_list))
# Out:
# 36

# %% [markdown]
# ### Task 2

# %%
def generate_permutations(s):
    """
    Generate all unique permutations of a string using recursion and backtracking.

    Args:
        s (str): The input string.

    Returns:
        list: A list containing all unique permutations of the string.
    """

    chars = sorted(s)
    results = set()

    def backtrack(path, used):
        if len(path) == len(chars):
            results.add("".join(path))
            return

        for i in range(len(chars)):
            if used[i]:
                continue

            if i > 0 and chars[i] == chars[i-1] and not used[i-1]:
                continue

            used[i] = True
            path.append(chars[i])

            backtrack(path, used)

            path.pop()
            used[i] = False

    backtrack([], [False] * len(chars))
    return sorted(results)

# %%
print(generate_permutations("abc"))
# Out:
# ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']

# %%
print(generate_permutations("aab"))
# Out:
# ['aab', 'aba', 'baa']

# %% [markdown]
# ### Task 3

# %%
def calculate_directory_size(directory):
  total_size = 0

  for key, value in directory.items():
      if isinstance(value, dict):
          total_size += calculate_directory_size(value)
      else:
          total_size += value

  return total_size

# %%
directory_structure = {
    "file1.txt": 200,
    "file2.txt": 300,
    "subdir1": {
        "file3.txt": 400,
        "file4.txt": 100
    },
    "subdir2": {
        "subsubdir1": {
            "file5.txt": 250
        },
        "file6.txt": 150
    }
}

print("Total size of the directory is:", calculate_directory_size(directory_structure), "KB")
# Out:
# Total size of the directory is: 1400 KB

# %% [markdown]
# ### Solving Fibonacci Sequnce with Memoization {Top - Down Approach}

# %%
def fibonacci(n, memo={}):
  """
  Computes the nth Fibonacci number using memoization to optimize the recursive
  solution.
  This function uses memoization to store previously computed Fibonacci numbers,
  reducing redundant calculations and improving performance.
  Parameters:
  n (int): The index in the Fibonacci sequence for which the value is to be computed.
          Must be a non-negative integer.
  memo (dict, optional): A dictionary used to store previously computed Fibonacci
    values.
  It is initialized as an empty dictionary by default and is used
  during the recursive calls to avoid recalculating results.

  Returns:
  int: The nth Fibonacci number.
  Example:
  >>> fibonacci(5)
  5
  >>> fibonacci(10)
  55
  Time Complexity:
  - The time complexity is O(n) because each Fibonacci number is computed only once.
  Space Complexity:
  - The space complexity is O(n) due to the memoization dictionary storing the results.
  """
  if n in memo:
    return memo[n]
  if n <= 1:
    return n
  memo[n] = fibonacci(n - 1, memo) + fibonacci(n - 2, memo)
  return memo[n]

# %% [markdown]
# ### Solving Fibonacci Sequnce with Tbulation {Bottom - Up Approach}

# %%
def fibonacci(n):
  """
  Computes the nth Fibonacci number using dynamic programming to optimize the solution.
  This function uses a bottom-up dynamic programming approach to calculate the nth
  Fibonacci number by iteratively building up an array of Fibonacci numbers up to n,
  thus eliminating redundant calculations and improving performance.

  Parameters:
    n (int): The index in the Fibonacci sequence for which the value is to be computed.
            Must be a non-negative integer.

  Returns:
    int: The nth Fibonacci number.

  Example:
    >>> fibonacci(5)
    5
    >>> fibonacci(10)
    55

  Time Complexity:
    - O(n), as the function iterates through values 2 to n, computing each once.

  Space Complexity:
  - O(n), due to the array used to store computed Fibonacci numbers.
  """

  if n <= 1:
    return n
  dp = [0] * (n + 1)
  dp[1] = 1
  for i in range(2, n + 1):
    dp[i] = dp[i - 1] + dp[i - 2]
  return dp[n]

# %% [markdown]
# ### Task1

# %%
def min_coins(coins, amount):
  """
  Finds the minimum number of coins needed to make up a given amount using dynamic
  programming.
  This function solves the coin change problem by determining the fewest number of
  coins from a given set of coin denominations that sum up to a target amount. The
  solution uses dynamic programming(tabulation) to iteratively build up the minimum
  number of coins required for each amount.
  Parameters:
  coins (list of int): A list of coin denominations available for making change. Each
  coin denomination is a positive integer.

  amount (int): The target amount for which we need to find the minimum number of coins
  . It must be a non-negative integer.
  Returns:
  int: The minimum number of coins required to make the given amount.
  If it is not possible to make the amount with the given coins, returns -1.
  Example:
  >>> min_coins([1, 2, 5], 11)
  3
  >>> min_coins([2], 3)
  -1
  """
  dp = [float("inf")] * (amount + 1)
  dp[0] = 0
  for coin in coins:
    for i in range(coin, amount + 1):
      dp[i] = min(dp[i], dp[i - coin] + 1)
  return dp[amount] if dp[amount] != float("inf") else -1

print(min_coins([1, 2, 5], 11))
# Out:
# 3

# %% [markdown]
# ### Task 2

# %%
def longest_common_subsequence(s1, s2):
  """
  Finds the length of the longest common subsequence (LCS) between two strings.
  Parameters:
  s1 (str): The first string.
  s2 (str): The second string.
  Returns:
  int: The length of the LCS of two strings s1 and s2.
  Example:
  >>> longest_common_subsequence("abcde", "ace")
  3
  """
  a, b = len(s1), len(s2)
  dp = [[0] * (b + 1) for _ in range(a + 1)]
  for i in range(1, a + 1):
      for j in range(1, b + 1):
          if s1[i - 1] == s2[j - 1]:
            dp[i][j] = dp[i - 1][j - 1] + 1
          else:
            dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])
  return dp[a][b]

# %%
print("Length of the LCS of two strings s1 and s2 is: ", longest_common_subsequence("abcde", "ace"))
# Out:
# Length of LCS: 3

# %% [markdown]
# ### Task 3

# %%
def knapsack(weights, values, capacity):
  """
  Solves the 0/1 Knapsack Problem using dynamic programming.
  Parameters:
    weights (list): List of item weights.
    values (list): List of item values (same length as weights).
    capacity (int): Maximum weight capacity of the knapsack.

  Returns:
    int: The maximum total value that can be carried without
    exceeding the weight capacity.

  Example:
    >>> knapsack([1, 3, 4, 5], [1, 4, 5, 7], 7)
    9
  """
  n = len(weights)
  dp = [[0] * (capacity + 1) for _ in range(n + 1)]
  for i in range(1, n + 1):
    for w in range(1, capacity + 1):
      if weights[i - 1] <= w:
        dp[i][w] = max(values[i-1] + dp[i-1][w - weights[i-1]], dp[i-1][w])
      else:
          dp[i][w] = dp[i - 1][w]
  return dp[n][capacity]

# %%
weights = [1, 3, 4, 5]
values = [1, 4, 5, 7]
capacity = 7

print("Maximun value is :", knapsack(weights, values, capacity))
# Out:
# Maximun value is : 9
